# %%
#Prerequisites

import sys
# !{sys.executable} -m pip install --user networkx
# !{sys.executable} -m pip install --user numpy
# !{sys.executable} -m pip install --user pandas

import networkx as nx
import numpy as np
import pandas as pd
import os

from pandas import DataFrame
# Out:
# Requirement already satisfied: networkx in /Users/jungmeepark/opt/anaconda3/lib/python3.9/site-packages (2.8.4)
# Requirement already satisfied: numpy in /Users/jungmeepark/opt/anaconda3/lib/python3.9/site-packages (1.21.5)
# Requirement already satisfied: pandas in /Users/jungmeepark/opt/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/jungmeepark/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/jungmeepark/opt/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/jungmeepark/opt/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /Users/jungmeepark/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Read in Source File - NB this must match the schema requirements
# read in data
initial_report_SF = pd.read_csv("~/Documents/Trellis/Network_Analysis_Tableau/data/initial-report-SF2.csv")
CodeType = 'latin1' # https://docs.python.org/3/library/codecs.html#standard-encodings
initial_report_SF
# Out:
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/1128244047.py:3: DtypeWarning: Columns (2,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   initial_report_SF = pd.read_csv("~/Documents/Trellis/Network_Analysis_Tableau/data/initial-report-SF2.csv")
#                           Appointment Name  Case Number Case Detail Name  \
# 0                   3/14/2024 - Ira Stokes          NaN              NaN
# 1                   3/28/2024 - Sonia Mora          NaN              NaN
# 2                 3/8/2024 - Bonnee Rendon          NaN              NaN
# 3       10/26/2023 - Aoife Brogan-Marshall          NaN              NaN
# 4               10/26/2023 - Sarah Kalleco          NaN              NaN
# ...                                    ...          ...              ...
# 119972          4/1/2024 - Samuel Martinez    2658465.0       CD-1521038
# 119973               4/1/2024 - Jiya Singh    2658471.0       CD-1521041
# 119974           4/1/2024 - Madison Rogers    2658472.0       CD-1521042
# 119975               4/1/2024 - Will Jones    2658479.0       CD-1521045
# 119976             4/1/2024 - Ruby Lenertz    2658482.0       CD-1521046
#
#         Owner: Owner ID  Contact EmplID          Case ID Appointment Date  \
# 0       0056R00000ELgqI             NaN              NaN          3/14/24
# 1       0053n000007d5uo             NaN              NaN          3/28/24
# 2       0052S000009vjRj             NaN              NaN           3/8/24
# 3       0052S000009vlCy             NaN              NaN         10/26/23
# 4       0053n00000844Wc             NaN              NaN         10/26/23
# ...                 ...             ...              ...              ...
# 119972  0053n000007NsoN      23871273.0  5006R00001zCVeW           4/1/24
# 119973  0052S00000AS2RV      23867493.0  5006R00001zCVfZ           4/1/24
# 119974  005f4000004dmIP             NaN  5006R00001zCVfe           4/1/24
# 119975  005f4000004dmIN      23737588.0  5006R00001zCVgr           4/1/24
# 119976  0052S000009vjRh      23716506.0  5006R00001zCVhB           4/1/24
#
#                    Advisor Name
# 0             Jennifer Wellborn
# 1          Emily Burruel Bonney
# 2       Abba Kris Maria Versace
# 3                    Dari Salvo
# 4               Fatimah Zamzeer
# ...                         ...
# 119972          Ursula Basinger
# 119973             Meaghan Shaw
# 119974       Stephanie Thiltges
# 119975          David McGuiggan
# 119976              Sandra Holm
#
# [119977 rows x 8 columns]

# %%
# Get variable names (column names) of the DataFrame
variable_names = initial_report_SF.columns

print(variable_names)
# Out:
# Index(['Appointment Name', 'Case Number', 'Case Detail Name',
#        'Owner: Owner ID', 'Contact EmplID', 'Case ID', 'Appointment Date',
#        'Advisor Name'],
#       dtype='object')

# %%
# Filter out rows where `Case ID` or `Contact EmplID` is NA or empty
filtered_df = initial_report_SF.dropna(subset=['Case Number', 'Case ID', 'Contact EmplID'])
#initial_report_SF = initial_report_SF[(~initial_report_SF['Case ID'].isna()) | (initial_report_SF['Case ID'] != "")]
#initial_report_SF = initial_report_SF[(~initial_report_SF['Contact EmplID'].isna()) | (initial_report_SF['Contact EmplID'] != "")]
print(filtered_df)
# Out:
#                   Appointment Name  Case Number Case Detail Name  \
# 66441   7/3/2023 - Helena Lassalle    2249069.0       CD-1405953
# 66442      7/3/2023 - Jp Cervantes    2249145.0       CD-1405955
# 66443        7/3/2023 - Bella Bush    2249152.0       CD-1405956
# 66444    7/3/2023 - Stelyne S Claw    2249181.0       CD-1405965
# 66445    7/3/2023 - Levin Mullaney    2249215.0       CD-1405978
# ...                            ...          ...              ...
# 119971      4/1/2024 - Sasha Bojic    2658460.0       CD-1521036
# 119972  4/1/2024 - Samuel Martinez    2658465.0       CD-1521038
# 119973       4/1/2024 - Jiya Singh    2658471.0       CD-1521041
# 119975       4/1/2024 - Will Jones    2658479.0       CD-1521045
# 119976     4/1/2024 - Ruby Lenertz    2658482.0       CD-1521046
#
#         Owner: Owner ID  Contact EmplID          Case ID Appointment Date  \
# 66441   0052S000009vjSY      23847450.0  5003n00002iJFYc           7/3/23
# 66442   0052S000009vIbI      23641362.0  5003n00002iJGhj           7/3/23
# 66443   0053n000007s0nJ      23828411.0  5003n00002iJG2a           7/3/23
# 66444   0052S000009vjS4      23531788.0  5003n00002iJGtU           7/3/23
# 66445   0052S000009vjSB      23883597.0  5003n00002iJHAu           7/3/23
# ...                 ...             ...              ...              ...
# 119971  0052S000009vjRf      23739591.0  5006R00001zCVdd           4/1/24
# 119972  0053n000007NsoN      23871273.0  5006R00001zCVeW           4/1/24
# 119973  0052S00000AS2RV      23867493.0  5006R00001zCVfZ           4/1/24
# 119975  005f4000004dmIN      23737588.0  5006R00001zCVgr           4/1/24
# 119976  0052S000009vjRh      23716506.0  5006R00001zCVhB           4/1/24
#
#              Advisor Name
# 66441   Stephanie Maxwell
# 66442        Monique Pena
# 66443           Rani Metz
# 66444     Josette Miranda
# 66445    Justin Schneider
# ...                   ...
# 119971    Bess Ecelbarger
# 119972    Ursula Basinger
# 119973       Meaghan Shaw
# 119975    David McGuiggan
# 119976        Sandra Holm
#
# [53013 rows x 8 columns]

# %%
# create new emplID's
# Extract unique IDs
unique_ids = filtered_df['Contact EmplID'].unique()

# Generate new IDs (random IDs)
np.random.seed(53013)  # for reproducibility
new_ids = np.random.randint(1000, 9999, len(unique_ids))

# Create a dictionary to map old IDs to new IDs
id_mapping = dict(zip(unique_ids, new_ids))

id_mapping
#filtered_df_newID=filtered_df.append(id_mapping,ignore_index=True)
# Out:
# {23847450.0: 4852,
#  23641362.0: 6239,
#  23828411.0: 7151,
#  23531788.0: 7072,
#  23883597.0: 7176,
#  23671959.0: 3311,
#  23735098.0: 3872,
#  23834358.0: 6729,
#  23406290.0: 5275,
#  23738884.0: 5000,
#  23875769.0: 8673,
#  23766145.0: 6469,
#  23862835.0: 9728,
#  23051847.0: 8573,
#  23648885.0: 8143,
#  23770105.0: 7141,
#  23766370.0: 2759,
#  23478571.0: 3115,
#  23827222.0: 8737,
#  23734541.0: 8372,
#  23773259.0: 2847,
#  23802318.0: 1218,
#  23504786.0: 9547,
#  23560965.0: 7306,
#  23719253.0: 5778,
#  23081507.0: 7210,
#  23796177.0: 6122,
#  23665070.0: 6612,
#  23712451.0: 6822,
#  23339983.0: 1997,
#  23762161.0: 5922,
#  23510664.0: 3198,
#  23682201.0: 6411,
#  23719837.0: 7200,
#  23836546.0: 2188,
#  23663037.0: 5157,
#  23806480.0: 5230,
#  23814228.0: 8688,
#  23809225.0: 6470,
#  23283819.0: 8624,
#  23781766.0: 7798,
#  23783951.0: 3182,
#  23455166.0: 3280,
#  23850118.0: 3557,
#  23567816.0: 3853,
#  23646388.0: 2775,
#  23543217.0: 8606,
#  23879348.0: 1239,
#  23676671.0: 8509,
#  23804665.0: 7826,
#  23676093.0: 9616,
#  23851878.0: 6143,
#  23410112.0: 1741,
#  23820159.0: 6693,
#  23713313.0: 9182,
#  23474691.0: 3076,
#  23800725.0: 3187,
#  23792013.0: 2105,
#  23857508.0: 9166,
#  23800419.0: 4807,
#  23875747.0: 1551,
#  23804218.0: 5360,
#  23678783.0: 8602,
#  23764623.0: 8181,
#  23687210.0: 4992,
#  23863468.0: 4188,
#  23815128.0: 4296,
#  23751260.0: 8814,
#  23778876.0: 2857,
#  22096702.0: 9283,
#  23699665.0: 7236,
#  23565580.0: 4143,
#  23816392.0: 2830,
#  23798535.0: 4966,
#  23648576.0: 5830,
#  23734782.0: 4683,
#  23737661.0: 4908,
#  23483841.0: 8244,
#  23882616.0: 5458,
#  23810161.0: 6502,
#  23451185.0: 3905,
#  23793452.0: 3272,
#  23807897.0: 2037,
#  23424449.0: 4492,
#  23785623.0: 6282,
#  23861280.0: 7841,
#  23800527.0: 4423,
#  23735384.0: 7421,
#  23878983.0: 9754,
#  23222370.0: 3622,
#  23876544.0: 5103,
#  23833237.0: 4873,
#  23791580.0: 5877,
#  23814041.0: 1322,
#  23581309.0: 8299,
#  23806587.0: 8439,
#  23879973.0: 5993,
#  23811273.0: 7128,
#  23798971.0: 5547,
#  23792975.0: 8661,
#  23699611.0: 5764,
#  23775184.0: 1685,
#  23746101.0: 4690,
#  23737708.0: 2413,
#  23882010.0: 8564,
#  23531753.0: 7838,
#  23734463.0: 7051,
#  23811594.0: 2965,
#  23683916.0: 9117,
#  23698223.0: 2073,
#  23829566.0: 5951,
#  23791643.0: 7487,
#  23879245.0: 8665,
#  23634845.0: 4659,
#  23696237.0: 2220,
#  2834164.0: 7353,
#  23802886.0: 2215,
#  23879991.0: 4597,
#  23703457.0: 9584,
#  23576796.0: 5781,
#  23881747.0: 2362,
#  23412751.0: 7106,
#  23660277.0: 5900,
#  23866579.0: 2953,
#  23532082.0: 5043,
#  23694282.0: 5365,
#  23378013.0: 8029,
#  23801477.0: 1952,
#  23612179.0: 6475,
#  23858284.0: 9464,
#  23754020.0: 8729,
#  23832886.0: 6302,
#  23436706.0: 3885,
#  23674030.0: 3997,
#  23825908.0: 7338,
#  23862350.0: 6721,
#  23879847.0: 7519,
#  23584135.0: 3625,
#  23825522.0: 3822,
#  23575660.0: 3186,
#  23743051.0: 3383,
#  23881479.0: 6478,
#  23649971.0: 3770,
#  23800232.0: 7327,
#  23503843.0: 1989,
#  23839101.0: 1051,
#  23471036.0: 9561,
#  23664944.0: 2705,
#  23701044.0: 4133,
#  23745278.0: 5561,
#  23881972.0: 1015,
#  23473494.0: 2322,
#  23842037.0: 3789,
#  23877897.0: 6587,
#  23837857.0: 7402,
#  23821323.0: 7296,
#  23756156.0: 7601,
#  23619230.0: 9518,
#  23876049.0: 2846,
#  23544191.0: 9509,
#  23650786.0: 1127,
#  23881563.0: 1892,
#  23790285.0: 8030,
#  23576944.0: 1903,
#  23879755.0: 8500,
#  23753921.0: 8590,
#  23579000.0: 5594,
#  23575495.0: 5371,
#  23488881.0: 9514,
#  23710025.0: 7173,
#  23848358.0: 5432,
#  23705926.0: 6504,
#  23870057.0: 6505,
#  23828196.0: 2143,
#  23520022.0: 7970,
#  23781830.0: 6668,
#  23860261.0: 1778,
#  23864789.0: 4450,
#  23858971.0: 4176,
#  23849311.0: 1534,
#  23829224.0: 3526,
#  23646428.0: 5190,
#  23822059.0: 6814,
#  23881494.0: 8190,
#  23599238.0: 2315,
#  23653250.0: 1947,
#  23797551.0: 9984,
#  23876223.0: 2757,
#  23712251.0: 5558,
#  23658138.0: 3283,
#  23881387.0: 2259,
#  ...}

# %%
# Get variable names (column names) of the DataFrame
variable_names = filtered_df.columns

print(variable_names)
# Out:
# Index(['Appointment Name', 'Case Number', 'Case Detail Name',
#        'Owner: Owner ID', 'Contact EmplID', 'Case ID', 'Appointment Date',
#        'Advisor Name'],
#       dtype='object')

# %%
#filtered_df['Contact EmplID'].map(id_mapping)  
filtered_df['New_ID'] = filtered_df['Contact EmplID'].map(id_mapping)
# Out:
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/1076181769.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['New_ID'] = filtered_df['Contact EmplID'].map(id_mapping)

# %%
print(filtered_df.head())
# Out:
#                  Appointment Name  Case Number Case Detail Name  \
# 66441  7/3/2023 - Helena Lassalle    2249069.0       CD-1405953
# 66442     7/3/2023 - Jp Cervantes    2249145.0       CD-1405955
# 66443       7/3/2023 - Bella Bush    2249152.0       CD-1405956
# 66444   7/3/2023 - Stelyne S Claw    2249181.0       CD-1405965
# 66445   7/3/2023 - Levin Mullaney    2249215.0       CD-1405978
#
#        Owner: Owner ID  Contact EmplID          Case ID Appointment Date  \
# 66441  0052S000009vjSY      23847450.0  5003n00002iJFYc           7/3/23
# 66442  0052S000009vIbI      23641362.0  5003n00002iJGhj           7/3/23
# 66443  0053n000007s0nJ      23828411.0  5003n00002iJG2a           7/3/23
# 66444  0052S000009vjS4      23531788.0  5003n00002iJGtU           7/3/23
# 66445  0052S000009vjSB      23883597.0  5003n00002iJHAu           7/3/23
#
#             Advisor Name  New_ID
# 66441  Stephanie Maxwell    4852
# 66442       Monique Pena    6239
# 66443          Rani Metz    7151
# 66444    Josette Miranda    7072
# 66445   Justin Schneider    7176

# %%
# create a new column to extract the names
# Extract just the names
filtered_df['Student Name'] = filtered_df['Appointment Name'].str.split(' - ', expand=True)[1]

# Display the updated DataFrame
print(filtered_df.head())
# Out:
#                  Appointment Name  Case Number Case Detail Name  \
# 66441  7/3/2023 - Helena Lassalle    2249069.0       CD-1405953
# 66442     7/3/2023 - Jp Cervantes    2249145.0       CD-1405955
# 66443       7/3/2023 - Bella Bush    2249152.0       CD-1405956
# 66444   7/3/2023 - Stelyne S Claw    2249181.0       CD-1405965
# 66445   7/3/2023 - Levin Mullaney    2249215.0       CD-1405978
#
#        Owner: Owner ID  Contact EmplID          Case ID Appointment Date  \
# 66441  0052S000009vjSY      23847450.0  5003n00002iJFYc           7/3/23
# 66442  0052S000009vIbI      23641362.0  5003n00002iJGhj           7/3/23
# 66443  0053n000007s0nJ      23828411.0  5003n00002iJG2a           7/3/23
# 66444  0052S000009vjS4      23531788.0  5003n00002iJGtU           7/3/23
# 66445  0052S000009vjSB      23883597.0  5003n00002iJHAu           7/3/23
#
#             Advisor Name  New_ID     Student Name
# 66441  Stephanie Maxwell    4852  Helena Lassalle
# 66442       Monique Pena    6239     Jp Cervantes
# 66443          Rani Metz    7151       Bella Bush
# 66444    Josette Miranda    7072   Stelyne S Claw
# 66445   Justin Schneider    7176   Levin Mullaney
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/4219599083.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Student Name'] = filtered_df['Appointment Name'].str.split(' - ', expand=True)[1]

# %%
# add an index column

filtered_df['index'] = range(1, len(filtered_df) + 1)
#filtered_df['index'] = filtered_df.index

# Display the updated DataFrame
#print(filtered_df.head())
# Out:
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/2883868708.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['index'] = range(1, len(filtered_df) + 1)

# %%
# create a source column
filtered_df['Source'] = filtered_df.groupby(['Advisor Name']).ngroup()

# Display the updated DataFrame
print(filtered_df.head(100))
# Out:
#                  Appointment Name  Case Number Case Detail Name  \
# 66441  7/3/2023 - Helena Lassalle    2249069.0       CD-1405953
# 66442     7/3/2023 - Jp Cervantes    2249145.0       CD-1405955
# 66443       7/3/2023 - Bella Bush    2249152.0       CD-1405956
# 66444   7/3/2023 - Stelyne S Claw    2249181.0       CD-1405965
# 66445   7/3/2023 - Levin Mullaney    2249215.0       CD-1405978
# ...                           ...          ...              ...
# 66536     7/5/2023 - Rachel Baker    2250659.0       CD-1406400
# 66537  7/3/2023 - Maritza Alvarez    2250682.0       CD-1406404
# 66538  7/5/2023 - Michael Bushrod    2250686.0       CD-1406405
# 66539        7/3/2023 - Ava Lopez    2250688.0       CD-1406406
# 66540   7/5/2023 - Jesenia Duenas    2250706.0       CD-1406409
#
#        Owner: Owner ID  Contact EmplID          Case ID Appointment Date  \
# 66441  0052S000009vjSY      23847450.0  5003n00002iJFYc           7/3/23
# 66442  0052S000009vIbI      23641362.0  5003n00002iJGhj           7/3/23
# 66443  0053n000007s0nJ      23828411.0  5003n00002iJG2a           7/3/23
# 66444  0052S000009vjS4      23531788.0  5003n00002iJGtU           7/3/23
# 66445  0052S000009vjSB      23883597.0  5003n00002iJHAu           7/3/23
# ...                ...             ...              ...              ...
# 66536  0053n0000088vVW      23581309.0  5003n00002iJW1w           7/5/23
# 66537  0053n0000084AJ8      23806587.0  5003n00002iJWJb           7/3/23
# 66538  0052S00000A6FmV      23879973.0  5003n00002iJWKK           7/5/23
# 66539  0053n0000084AJ8      23811273.0  5003n00002iJWFp           7/3/23
# 66540  0052S000009vIbI      23798971.0  5003n00002iJWTd           7/5/23
#
#             Advisor Name  New_ID     Student Name  index  Source_col  Source
# 66441  Stephanie Maxwell    4852  Helena Lassalle      1         NaN     249
# 66442       Monique Pena    6239     Jp Cervantes      2         NaN     205
# 66443          Rani Metz    7151       Bella Bush      3         NaN     222
# 66444    Josette Miranda    7072   Stelyne S Claw      4         NaN     135
# 66445   Justin Schneider    7176   Levin Mullaney      5         NaN     140
# ...                  ...     ...              ...    ...         ...     ...
# 66536      Amanda Bogden    8299     Rachel Baker     96         NaN      15
# 66537      Chaz DeCoteau    8439  Maritza Alvarez     97         NaN      50
# 66538       Mike Coleman    5993  Michael Bushrod     98         NaN     202
# 66539      Chaz DeCoteau    7128        Ava Lopez     99         NaN      50
# 66540       Monique Pena    5547   Jesenia Duenas    100         NaN     205
#
# [100 rows x 13 columns]
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/2590767095.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Source'] = filtered_df.groupby(['Advisor Name']).ngroup()

# %%
# Convert 'Appointment Date' column to datetime
filtered_df['AppointmentDate'] = pd.to_datetime(filtered_df['Appointment Date'])

# Calculate today's date
today = pd.to_datetime('today').normalize()
filtered_df['today'] = today

# Calculate days since 'AppointmentDate'
filtered_df['days_since'] = (filtered_df['today'] - filtered_df['AppointmentDate']).dt.days

# Display the updated DataFrame
print(filtered_df.head())
# Out:
#                  Appointment Name  Case Number Case Detail Name  \
# 66441  7/3/2023 - Helena Lassalle    2249069.0       CD-1405953
# 66442     7/3/2023 - Jp Cervantes    2249145.0       CD-1405955
# 66443       7/3/2023 - Bella Bush    2249152.0       CD-1405956
# 66444   7/3/2023 - Stelyne S Claw    2249181.0       CD-1405965
# 66445   7/3/2023 - Levin Mullaney    2249215.0       CD-1405978
#
#        Owner: Owner ID  Contact EmplID          Case ID Appointment Date  \
# 66441  0052S000009vjSY      23847450.0  5003n00002iJFYc           7/3/23
# 66442  0052S000009vIbI      23641362.0  5003n00002iJGhj           7/3/23
# 66443  0053n000007s0nJ      23828411.0  5003n00002iJG2a           7/3/23
# 66444  0052S000009vjS4      23531788.0  5003n00002iJGtU           7/3/23
# 66445  0052S000009vjSB      23883597.0  5003n00002iJHAu           7/3/23
#
#             Advisor Name  New_ID     Student Name  index  Source_col  Source  \
# 66441  Stephanie Maxwell    4852  Helena Lassalle      1         NaN     249
# 66442       Monique Pena    6239     Jp Cervantes      2         NaN     205
# 66443          Rani Metz    7151       Bella Bush      3         NaN     222
# 66444    Josette Miranda    7072   Stelyne S Claw      4         NaN     135
# 66445   Justin Schneider    7176   Levin Mullaney      5         NaN     140
#
#       AppointmentDate      today  days_since
# 66441      2023-07-03 2024-04-19         291
# 66442      2023-07-03 2024-04-19         291
# 66443      2023-07-03 2024-04-19         291
# 66444      2023-07-03 2024-04-19         291
# 66445      2023-07-03 2024-04-19         291
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/3035720014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['AppointmentDate'] = pd.to_datetime(filtered_df['Appointment Date'])
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/3035720014.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['today'] = today
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/3035720014.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['days_since'] = (filtered_df['today'] - filtered_df['AppointmentDate']).dt.days

# %%
filtered_df = filtered_df.rename(columns={'Owner: Owner ID': 'owner_id', 'New_ID': 'Target'})

# %%
filtered_df['Source'] = filtered_df['Source'].map(str)
filtered_df['Target'] = filtered_df['Target'].map(str)

# %%
# Add directions to d3
filtered_df['Direction'] = filtered_df['Source'] + ' -> ' + filtered_df['Target']

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53013 entries, 66441 to 119976
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Appointment Name  53013 non-null  object
#  1   Case Number       53013 non-null  float64
#  2   Case Detail Name  52829 non-null  object
#  3   owner_id          53013 non-null  object
#  4   Contact EmplID    53013 non-null  float64
#  5   Case ID           53013 non-null  object
#  6   Appointment Date  53013 non-null  object
#  7   Advisor Name      53013 non-null  object
#  8   Target            53013 non-null  object
#  9   Student Name      53013 non-null  object
#  10  index             53013 non-null  int64
#  11  Source_col        0 non-null      float64
#  12  Source            53013 non-null  object
#  13  AppointmentDate   53013 non-null  datetime64[ns]
#  14  today             53013 non-null  datetime64[ns]
#  15  days_since        53013 non-null  int64
#  16  Direction         53013 non-null  object
# dtypes: datetime64[ns](2), float64(3), int64(2), object(10)
# memory usage: 7.3+ MB

# %%
# FOLLOWING KNIPPENBERG

# Save the DataFrame to a CSV file

filtered_df.to_csv('~/Documents/Trellis/Network_Analysis_Tableau/data/generated_from_knipp/py-filtered_df.csv', index=False)  # Set index=False to exclude the index from the CSV file
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/wr/p82k0vm11j17r80bp7wf3swc0000gs/T/ipykernel_17708/3701323784.py in <module>
#       3 # Save the DataFrame to a CSV file
#       4
# ----> 5 filtered_df.to_csv("../data/py-filtered_df.csv", index=False)  # Set index=False to exclude the index from the CSV file
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1178             formatter=self.fmt,
#    1179         )
# -> 1180         csv_formatter.save()
#    1181
#    1182         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/csvs.py in save(self)
#     239         """
#     240         # apply compression and byte/text conversion
# --> 241         with get_handle(
#     242             self.filepath_or_buffer,
#     243             self.mode,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     692     # Only for write methods
#     693     if "r" not in mode and is_path:
# --> 694         check_parent_directory(str(handle))
#     695
#     696     if compression:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in check_parent_directory(path)
#     566     parent = Path(path).parent
#     567     if not parent.is_dir():
# --> 568         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     569
#     570
#
# OSError: Cannot save file into a non-existent directory: '../data'

# %%
reduced_df = filtered_df.sample(n=300)

# %%
arr_SrcTgt = np.array(reduced_df[['Source','Target']])

# %%
# Create Network Graph Coordinates...
Q = nx.Graph()
Q.add_edges_from(arr_SrcTgt)
dict_Coords = nx.spring_layout(Q)

# %%
# Create Graph Coordinates File...
df_Raw_Coords = DataFrame(dict_Coords)
df_Raw_Coords = df_Raw_Coords.T
df_Raw_Coords.columns = ['X','Y']
df_Raw_Coords.to_csv('~/Documents/Trellis/Network_Analysis_Tableau/data/generated_from_knipp/CoordsFile.csv', index_label='NodeName')
print(df_Raw_Coords)
# Out:
#              X         Y
# 224   0.404200 -0.067803
# 4824  0.410339 -0.086822
# 84    0.840680 -0.137113
# 3155  0.874670 -0.143313
# 200   0.733973  0.420898
# ...        ...       ...
# 6533  0.554393  0.179980
# 2862  0.440165 -0.641750
# 6401  0.934736 -0.192994
# 9707 -0.827440 -0.435135
# 3299 -0.586445 -0.704183
#
# [429 rows x 2 columns]

# %%
# Create Bridge File... 
# Tableau Code: IF [Src-Tgt]/2 = ROUND([Src-Tgt]/2) THEN 'Source' ELSE 'Target' END
arr_SrcTgt2 = arr_SrcTgt.reshape(1,(len(arr_SrcTgt)*2)) 
arr_SrcTgt2 = arr_SrcTgt2.reshape(-1) 
df_SrcTgt = DataFrame(arr_SrcTgt2,columns=['NodeName']) 
arr_Index = []
for i in range(1,(len(arr_SrcTgt)+1)):
    arr_Index.append(i)
    arr_Index.append(i)
df_SrcTgt['c_Index'] = arr_Index 
df_SrcTgt.to_csv('~/Documents/Trellis/Network_Analysis_Tableau/data/generated_from_knipp/BridgeFile.csv',index_label='Src-Tgt')

print('Run Completed Successfully')
# Out:
# Run Completed Successfully
